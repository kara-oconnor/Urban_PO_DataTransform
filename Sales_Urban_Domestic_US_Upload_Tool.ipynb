# %% [markdown]
# <a href="https://colab.research.google.com/github/BAGGU/BAGGU.github.io/blob/master/Sales_Urban_Domestic_US_Upload_Tool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import Libraries 📚

# %%
# Import our different packages, we'll use datascience, numpy, and pandas!
from datascience import *
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
pd.options.mode.chained_assignment = None  # default='warn'
import datetime

# %% [markdown]
# ### Upload Urban PO Data and Change File Name 📝

# %%
# Upload the Urban Outfitter data here 
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1f765789-01f3-421b-af25-c605e182c631" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1f765789-01f3-421b-af25-c605e182c631">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
# Initially import our Urban data - Be sure to rename the excel sheet below to your uploaded sheet!
initial_import= pd.read_excel('PO3678000.xlsx') # <- Change name here

# %% [markdown]
# ### Processing ⚙️

# %%
# Select the columns we want
# subs_data = initial_import[['Name','Address 1']]
subs_data = initial_import[['PO#','Vendor Style #','Vendor','Ship Date','Cancel Date','Ship To','Brand','Channel','Ttl Units', 'Retail', 'FOB Price']]
# subs_data['Ship To Name'] = ''
subs_data
subs_data.insert(loc=0,
          column='Ship To Name',
          value='')
subs_data.insert(loc=1,
          column='Address 1',
          value='')
subs_data.insert(loc=2,
          column='Address 2',
          value='')
subs_data.insert(loc=3,
          column='City',
          value='')
subs_data.insert(loc=4,
          column='State',
          value='')
subs_data.insert(loc=5,
          column='Zip Code',
          value='')
subs_data.insert(loc=6,
          column='Phone',
          value='')
subs_data.insert(loc=7,
          column='Email',
          value='')

# %%
#Update Shipping Address Information based on 3 Letter code

#RNO
subs_data['Ship To Name'] = np.where(subs_data['Ship To'] == "RNO", "Reno Direct DC (RNO)", subs_data['Ship To Name'])
subs_data['Address 1'] = np.where(subs_data['Ship To'] == "RNO", "12055 Moya Blvd.", subs_data['Address 1'])
subs_data['Address 2'] = np.where(subs_data['Ship To'] == "RNO", "", subs_data['Address 2'])
subs_data['City'] = np.where(subs_data['Ship To'] == "RNO", "Reno", subs_data['City'])
subs_data['State'] = np.where(subs_data['Ship To'] == "RNO", "NV", subs_data['State'])
subs_data['Zip Code'] = np.where(subs_data['Ship To'] == "RNO", "89506", subs_data['Zip Code'])
subs_data['Phone'] = np.where(subs_data['Ship To'] == "RNO", "775-971-1362", subs_data['Phone'])
subs_data['Email'] = np.where(subs_data['Ship To'] == "RNO", "RNODirectAppointments@urbanout.com ", subs_data['Email'])
#GFC
subs_data['Ship To Name'] = np.where(subs_data['Ship To'] == "GFC", "Gap Direct DC (GFC)", subs_data['Ship To Name'])
subs_data['Address 1'] = np.where(subs_data['Ship To'] == "GFC", "766 Brackbill Rd.", subs_data['Address 1'])
subs_data['Address 2'] = np.where(subs_data['Ship To'] == "GFC", "", subs_data['Address 2'])
subs_data['City'] = np.where(subs_data['Ship To'] == "GFC", "Gap", subs_data['City'])
subs_data['State'] = np.where(subs_data['Ship To'] == "GFC", "PA", subs_data['State'])
subs_data['Zip Code'] = np.where(subs_data['Ship To'] == "GFC", "17527", subs_data['Zip Code'])
subs_data['Phone'] = np.where(subs_data['Ship To'] == "GFC", "717-442-1000 ext. 2120", subs_data['Phone'])
subs_data['Email'] = np.where(subs_data['Ship To'] == "GFC", "GapFCReceivingGroup@urbanout.com", subs_data['Email'])
#REN
subs_data['Ship To Name'] = np.where(subs_data['Ship To'] == "REN", "Reno Retail DC (REN)", subs_data['Ship To Name'])
subs_data['Address 1'] = np.where(subs_data['Ship To'] == "REN", "6640 Echo Ave.", subs_data['Address 1'])
subs_data['Address 2'] = np.where(subs_data['Ship To'] == "REN", "", subs_data['Address 2'])
subs_data['City'] = np.where(subs_data['Ship To'] == "REN", "Reno", subs_data['City'])
subs_data['State'] = np.where(subs_data['Ship To'] == "REN", "NV", subs_data['State'])
subs_data['Zip Code'] = np.where(subs_data['Ship To'] == "REN", "89506", subs_data['Zip Code'])
subs_data['Phone'] = np.where(subs_data['Ship To'] == "REN", "775-971-1316", subs_data['Phone'])
subs_data['Email'] = np.where(subs_data['Ship To'] == "REN", "RenoRetailAppt@urbanout.com", subs_data['Email'])
#GAP
subs_data['Ship To Name'] = np.where(subs_data['Ship To'] == "GAP", "Gap Retail DC (GAP)", subs_data['Ship To Name'])
subs_data['Address 1'] = np.where(subs_data['Ship To'] == "GAP", "755 Brackbill Rd.", subs_data['Address 1'])
subs_data['Address 2'] = np.where(subs_data['Ship To'] == "GAP", "", subs_data['Address 2'])
subs_data['City'] = np.where(subs_data['Ship To'] == "GAP", "Gap", subs_data['City'])
subs_data['State'] = np.where(subs_data['Ship To'] == "GAP", "PA", subs_data['State'])
subs_data['Zip Code'] = np.where(subs_data['Ship To'] == "GAP", "17527", subs_data['Zip Code'])
subs_data['Phone'] = np.where(subs_data['Ship To'] == "GAP", "717-442-1208", subs_data['Phone'])
subs_data['Email'] = np.where(subs_data['Ship To'] == "GAP", "GAPDCRECEIVING@urbanout.com", subs_data['Email'])
#KC2
subs_data['Ship To Name'] = np.where(subs_data['Ship To'] == "KC2", "Kansas City, Missouri Fulfillment Center (KC2)", subs_data['Ship To Name'])
subs_data['Address 1'] = np.where(subs_data['Ship To'] == "KC2", "7501 W. 106th Terrace", subs_data['Address 1'])
subs_data['Address 2'] = np.where(subs_data['Ship To'] == "KC2", "", subs_data['Address 2'])
subs_data['City'] = np.where(subs_data['Ship To'] == "KC2", "Kansas City", subs_data['City'])
subs_data['State'] = np.where(subs_data['Ship To'] == "KC2", "MO", subs_data['State'])
subs_data['Zip Code'] = np.where(subs_data['Ship To'] == "KC2", "64153", subs_data['Zip Code'])
subs_data['Phone'] = np.where(subs_data['Ship To'] == "KC2", "", subs_data['Phone'])
subs_data['Email'] = np.where(subs_data['Ship To'] == "KC2", "KCInbound@urbn.onmicrosoft.com", subs_data['Email'])
#IFC
subs_data['Ship To Name'] = np.where(subs_data['Ship To'] == "IFC", "Indiana Fulfillment Center (IFC) Urban Outfitters DC", subs_data['Ship To Name'])
subs_data['Address 1'] = np.where(subs_data['Ship To'] == "IFC", "501 Windy Ridge Road", subs_data['Address 1'])
subs_data['Address 2'] = np.where(subs_data['Ship To'] == "IFC", "", subs_data['Address 2'])
subs_data['City'] = np.where(subs_data['Ship To'] == "IFC", "Indiana", subs_data['City'])
subs_data['State'] = np.where(subs_data['Ship To'] == "IFC", "PA", subs_data['State'])
subs_data['Zip Code'] = np.where(subs_data['Ship To'] == "IFC", "15701", subs_data['Zip Code'])
subs_data['Phone'] = np.where(subs_data['Ship To'] == "IFC", "724-822-9121", subs_data['Phone'])
subs_data['Email'] = np.where(subs_data['Ship To'] == "IFC", "IFCreceiving@urbanout.com", subs_data['Email'])
#BRO
subs_data['Ship To Name'] = np.where(subs_data['Ship To'] == "IFC", "Bristol Rental DC (BRO)", subs_data['Ship To Name'])
subs_data['Address 1'] = np.where(subs_data['Ship To'] == "IFC", "2401 Green Lane", subs_data['Address 1'])
subs_data['Address 2'] = np.where(subs_data['Ship To'] == "IFC", "", subs_data['Address 2'])
subs_data['City'] = np.where(subs_data['Ship To'] == "IFC", "Levittown", subs_data['City'])
subs_data['State'] = np.where(subs_data['Ship To'] == "IFC", "PA", subs_data['State'])
subs_data['Zip Code'] = np.where(subs_data['Ship To'] == "IFC", "19057", subs_data['Zip Code'])
subs_data['Phone'] = np.where(subs_data['Ship To'] == "IFC", "267-452-1036", subs_data['Phone'])
subs_data['Email'] = np.where(subs_data['Ship To'] == "IFC", "", subs_data['Email'])
final_dataframe = subs_data
final_dataframe["Zip Code"] = final_dataframe["Zip Code"].astype(str)
#final_dataframe

# %%
#Initialize The Export File
#blankdf['Order Number'] = finalDF['Name']
blankdf = pd.DataFrame()
blankdf['customer_po'] = final_dataframe['PO#']
blankdf['customer_name'] = 'Urban Outfitters'
blankdf['division_name'] = 'Key - Inline'
blankdf['warehouse_name'] = '(A) Quiet Logistics'
blankdf['date'] = pd.Timestamp("today").strftime("%m/%d/%y")
blankdf['date_start'] = pd.Timestamp("today").strftime("%m/%d/%y")
blankdf['date_due'] = '' # now empty
blankdf['department_number'] = ''
blankdf['credit_status'] = 'Approved'
blankdf['salesperson_name'] = 'Fiona Nugent'
blankdf['season'] = ''
blankdf['terms_name'] = 'Net 30'
blankdf['ship_via_name'] = 'FedEx Ground'
blankdf['shipping_terms_name'] = 'FedEx Prepaid'
blankdf['ship_to_name'] = final_dataframe['Ship To Name']
blankdf['ship_to_address_1'] = final_dataframe['Address 1']
blankdf['ship_to_address_2'] = final_dataframe['Address 2']
blankdf['ship_to_city'] = final_dataframe['City']
blankdf['ship_to_state'] = final_dataframe['State']
blankdf['ship_to_postal_code'] = final_dataframe['Zip Code']
blankdf['ship_to_country'] = 'US'
blankdf['ship_to_phone'] = final_dataframe['Phone']
blankdf['mark_for_store'] = ''
blankdf['dc_reference'] = ''
blankdf['tax_rate'] = ''
blankdf['percent_discount'] = ''
blankdf['amount_freight'] = ''
blankdf['qty_misc'] = ''
blankdf['rate_misc'] = ''
blankdf['description_misc'] = ''
blankdf['shipping_info'] = ''
blankdf['currency_rate'] = ''
blankdf['order_notes'] = ''
blankdf['order_private_notes'] = ''
blankdf['upc'] = final_dataframe['Vendor Style #']
blankdf['style_number'] = ''
blankdf['attr_2'] = ''
blankdf['attr_3'] = ''
blankdf['size'] = ''
blankdf['item_notes'] = ''
blankdf['qty'] = final_dataframe['Ttl Units']
# blankdf['unit_price'] = (final_dataframe['Retail']/2)*.87
blankdf['unit_price'] = (final_dataframe['FOB Price'])
blankdf['site_id'] = final_dataframe['Channel']

#just replacing some strings here 
blankdf['site_id'] = blankdf['site_id'].str.replace("DIRECT", "UrbanDirect")
blankdf['site_id'] = blankdf['site_id'].str.replace("RETAIL", "UrbanRetail")

blankdf['cancel_date'] = '' #need to confirm with Mylea
blankdf['customer_cancel_date'] = final_dataframe['Cancel Date'] # Urban Outfitters Cancel Date
#blankdf['order_season'] = '' HAVE TO ADD

# %%
# BDay is business day, not birthday...
from pandas.tseries.offsets import BDay

today = datetime.datetime.today()

# QL/ Ship Cancel = UO Cancel(aka date due in blankdf) - BDay(5) 
blankdf['customer_cancel_date'] = pd.to_datetime(blankdf['customer_cancel_date'])
blankdf['cancel_date'] = blankdf['customer_cancel_date'] - BDay(5)



# Subtracts Cencel date by days depending on if weekend or Saturday or Sunday 
blankdf['weekday'] = blankdf['customer_cancel_date'].dt.dayofweek
blankdf.loc[blankdf['weekday'] <= 4, "date_due"] = (blankdf['customer_cancel_date'] - datetime.timedelta(14)) # if weekday
blankdf.loc[blankdf['weekday'] == 5, "date_due"] = (blankdf['customer_cancel_date'] - datetime.timedelta(15)) # if Sat
blankdf.loc[blankdf['weekday'] == 6, "date_due"] = (blankdf['customer_cancel_date'] - datetime.timedelta(16)) # if Sun


# This allows it to revert back to string(uneditable by numbers)

# Would also need to do this for test/change name if we do it in new column 
blankdf['date_due'] = blankdf['date_due'].dt.strftime("%m/%d/%y") 
blankdf['customer_cancel_date'] = blankdf['customer_cancel_date'].dt.strftime("%m/%d/%Y") 
blankdf['cancel_date'] = blankdf['cancel_date'].dt.strftime("%m/%d/%Y")
del blankdf['weekday']

# %% [markdown]
# ### Review and Rename 👀

# %%
blankdf
# Out:
#    customer_po     customer_name  ... cancel_date customer_cancel_date
# 0      3678000  Urban Outfitters  ...  03/23/2022           03/30/2022
# 1      3678000  Urban Outfitters  ...  03/23/2022           03/30/2022
# 2      3678000  Urban Outfitters  ...  03/23/2022           03/30/2022
# 3      3678000  Urban Outfitters  ...  03/23/2022           03/30/2022
# 4      3678000  Urban Outfitters  ...  03/23/2022           03/30/2022
#
# [5 rows x 45 columns]

# %%
Blankdf_export = blankdf.to_csv('3678000.csv', index=False) # <- Change the name of the CSV before Run All
Blankdf_export

# File should now be available to download to the right in the folder button 
# Reminder to not open the file in excel! Only preview with space on finder.
